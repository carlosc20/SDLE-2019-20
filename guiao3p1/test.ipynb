# %%
import sys
import networkx as nx
import matplotlib.pyplot as plt
import graphGen
import simulator

# %%
def main():
    G = graphGen.randomG(12, 10) # gera grafo
    nodes, distances = simulator.connector(G) # converte grafo gerado em input para simulador
    sim = simulator.Sim(nodes, distances) # cria classe
    time = sim.start(0, "diz olá")  # primeira msg/inicio
    print("finished with: ", time)
    nx.draw(G, with_labels=True)


if __name__ == "__main__":
    main()
# Out:
# [(10, (0, 9, 'ola')), (10, (0, 11, 'ola'))]
# c_time:  0
# [(10, (0, 9, 'ola')), (20, (11, 9, 'ola')), (20, (11, 2, 'ola')), (20, (11, 0, 'ola'))]
# c_time:  10
# [(20, (11, 9, 'ola')), (20, (11, 2, 'ola')), (20, (11, 0, 'ola')), (20, (9, 2, 'ola')), (20, (9, 3, 'ola')), (20, (9, 1, 'ola')), (20, (9, 11, 'ola')), (20, (9, 0, 'ola')), (20, (9, 10, 'ola'))]
# c_time:  10
# [(20, (11, 9, 'ola')), (20, (11, 2, 'ola')), (20, (11, 0, 'ola')), (20, (9, 2, 'ola')), (20, (9, 3, 'ola')), (20, (9, 1, 'ola')), (20, (9, 11, 'ola')), (20, (9, 0, 'ola')), (30, (10, 9, 'ola'))]
# c_time:  20
# [(20, (11, 9, 'ola')), (20, (11, 2, 'ola')), (20, (11, 0, 'ola')), (20, (9, 2, 'ola')), (20, (9, 3, 'ola')), (30, (10, 9, 'ola')), (30, (1, 9, 'ola')), (30, (1, 2, 'ola'))]
# c_time:  20
# [(20, (11, 9, 'ola')), (20, (11, 2, 'ola')), (20, (11, 0, 'ola')), (20, (9, 2, 'ola')), (30, (10, 9, 'ola')), (30, (1, 9, 'ola')), (30, (1, 2, 'ola')), (30, (3, 6, 'ola')), (30, (3, 9, 'ola'))]
# c_time:  20
# [(20, (11, 9, 'ola')), (20, (11, 2, 'ola')), (20, (11, 0, 'ola')), (30, (10, 9, 'ola')), (30, (1, 9, 'ola')), (30, (1, 2, 'ola')), (30, (3, 6, 'ola')), (30, (3, 9, 'ola')), (30, (2, 9, 'ola')), (30, (2, 4, 'ola')), (30, (2, 11, 'ola')), (30, (2, 7, 'ola')), (30, (2, 1, 'ola'))]
# c_time:  20
# [(30, (10, 9, 'ola')), (30, (1, 9, 'ola')), (30, (1, 2, 'ola')), (30, (3, 6, 'ola')), (30, (3, 9, 'ola')), (30, (2, 9, 'ola')), (30, (2, 4, 'ola')), (30, (2, 11, 'ola')), (40, (7, 5, 'ola')), (40, (7, 2, 'ola'))]
# c_time:  30
# [(30, (10, 9, 'ola')), (30, (1, 9, 'ola')), (30, (1, 2, 'ola')), (30, (3, 6, 'ola')), (30, (3, 9, 'ola')), (30, (2, 9, 'ola')), (40, (7, 5, 'ola')), (40, (7, 2, 'ola')), (40, (4, 2, 'ola'))]
# c_time:  30
# [(30, (10, 9, 'ola')), (30, (1, 9, 'ola')), (30, (1, 2, 'ola')), (40, (7, 5, 'ola')), (40, (7, 2, 'ola')), (40, (4, 2, 'ola')), (40, (6, 3, 'ola'))]
# c_time:  30
# [(50, (5, 7, 'ola')), (50, (5, 8, 'ola'))]
# c_time:  40
# [(50, (5, 7, 'ola')), (60, (8, 5, 'ola'))]
# c_time:  50
# finished with:  60
